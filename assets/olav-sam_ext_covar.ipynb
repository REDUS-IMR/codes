# %%
# Install dependencies
install.packages("remotes")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Install SAM
remotes::install_github("fishfollower/SAM/stockassessment")
# Out:
# Skipping install of 'stockassessment' from a github remote, the SHA1 (cbf77ca4) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
# Clone SAM github repository
system("git clone https://github.com/fishfollower/SAM.git")

# %%
# Go into nscodcovar test
setwd("SAM/testmore/nscodcovar")

# %%
# Run demo
source("script.R")
# Out:
# Constructing atomic matinv
# Constructing atomic matinv
# Constructing atomic matmul
# Constructing atomic matinv
# Constructing atomic matmul
# Optimizing tape... Done
# iter: 1  value: 1232.562 mgc: 85.60345 ustep: 1
# iter: 2  value: 1087.496 mgc: 6.819088 ustep: 0.4367355
# iter: 3  value: 691.9822 mgc: 15.76552 ustep: 0.6608936
# iter: 4  value: 650.076 mgc: 1.404685 ustep: 0.8129723
# iter: 5  value: 646.3448 mgc: 0.2500957 ustep: 0.9016596
# iter: 6  value: 645.7887 mgc: 0.09054394 ustep: 0.9495626
# iter: 7  value: 645.6425 mgc: 0.04588253 ustep: 0.9744576
# iter: 8  value: 645.6151 mgc: 0.01596879 ustep: 0.9871475
# iter: 9  value: 645.6128 mgc: 0.004772102 ustep: 0.9935536
# iter: 10  value: 645.6127 mgc: 0.0006154952 ustep: 0.9967719
# iter: 11  value: 645.6127 mgc: 2.848711e-05 ustep: 0.9983848
# iter: 12  value: 645.6127 mgc: 8.95581e-07 ustep: 0.9991922
# iter: 13  value: 645.6127 mgc: 1.594116e-08 ustep: 0.999596
# iter: 14  mgc: 1.374095e-10
# ...

# %%
# Print results
print(modeltable(c("ESTMATED"=fit, "ASSIGNEDcor"=fit2,  "ASSIGNEDcov"=fit3,  "ASSIGNEDcov-weight"=fit4)))
# Out:
#                       log(L) #par      AIC
# ESTMATED           -276.9702   18 589.9404
# ASSIGNEDcor        -276.9702   17 587.9404
# ASSIGNEDcov        -276.9702   13 579.9404
# ASSIGNEDcov-weight -276.9702   14 581.9404

# %%
plot(fit)
# Out:
# plot without title

# %%
plot(fit2)
# Out:
# plot without title

# %%
plot(fit3)
# Out:
# plot without title
