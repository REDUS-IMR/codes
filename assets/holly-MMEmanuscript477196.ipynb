# %%
# Install dependencies
install.packages(c("remotes","tidyverse","RColorBrewer","extrafont","ncdf4"))
# Out:
# also installing the dependencies ‘extrafontdb’, ‘Rttf2pt1’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
remotes::install_github('Atlantis-Ecosystem-Model/ReactiveAtlantis')
remotes::install_github("alketh/atlantistools")
# Out:
# Skipping install of 'ReactiveAtlantis' from a github remote, the SHA1 (2bc6ee19) has not changed since last install.
#   Use `force = TRUE` to force installation
#
# ...
# shape        (NA -> 1.4.5 ) [CRAN]
# GlobalOpt... (NA -> 0.1.2 ) [CRAN]
# RNetCDF      (NA -> 2.4-2 ) [CRAN]
# proj4        (NA -> 1.0-10) [CRAN]
# circlize     (NA -> 0.4.12) [CRAN]
# Installing 5 packages: shape, GlobalOptions, RNetCDF, proj4, circlize
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# ✔  checking for file ‘/tmp/RtmpHNE59c/remotes8f0c48b1a42d/alketh-atlantistools-265dec6/DESCRIPTION’ (359ms)
# ─  preparing ‘atlantistools’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘atlantistools_0.4.3.9000.tar.gz’

# %%
install.packages(c("rbgm", "fmsb"))
# Out:
# also installing the dependencies ‘PROJ’, ‘crsmeta’, ‘geometries’, ‘raster’, ‘reproj’, ‘sfheaders’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Run 
source("R_script_figures.R", echo = TRUE)
# Out:
# > library(tidyverse)
#
# > library(RColorBrewer)
#
# > library(extrafont)
#
# > library(ncdf4)
#
# > get_PrimaryProduction <- function(fids, PRODnc, BGMfile) {
# +     nc <- nc_open(PRODnc)
# +     bboxes <- get_boundary(boxinfo = load_box(bgm = file.pa .... [TRUNCATED]
#
# > ExtractFromNCatltools <- function(fids, init, prm_biol,
# +     plgn, nc_out, prm_run, fids_age, fids_pool) {
# +     print("!!!!!")
# +     print("Pleas ..." ... [TRUNCATED]
#
# > nordic.group.data <- read.table("input_files/nordic_groups_Oil.csv",
# +     dec = ".", sep = ",", header = TRUE)
#
# > nordic.group.data <- nordic.group.data[which(nordic.group.data$IsTurnedOn ==
# +     1), ]
#
# > File_bgm <- "input_files/Nordic02.bgm"
#
# > toutinc <- 73
#
# > eventyr <- 61
#
# > basic = read.table("input_files/NOBA_BasicInfo_Oil.csv",
# +     header = T, sep = ";", na.strings = "NA", stringsAsFactors = F)
#
# > folder0 = "output_00_26.01.19"
#
# > folder10 = "output_10_26.01.19"
#
# ...
