# %%
# Install dependencies
install.packages(c("remotes", "dplyr", "MASS", "filelock", "copula","triangle", "coda", "latticeExtra"))
install.packages(c("mse", "FLa4a", "FLash", "FLAssess", "ggplotFL", "FLBRP", "FLCore"), repos="http://flr-project.org/R")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Install gadgetr
install.packages("gadgetr", repos = "https://redus-imr.github.io/gadget")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Clone the repository
system("git clone https://github.com/dgoto2/flr-gadget.git")
setwd("flr-gadget")
system("git checkout 31f9ef497f76e49f0266511217ffec5fb8a89fdf")

# %%
# Remove several lines as we don't use R studio
system("tail -n +8 flr-gadget_had.R > flr-gadget_had2.R")
# Don't use SAM, use SCAA instead
system("sed -i 's/- \"SAM\"/- \"SCAA\"/g' flr-gadget_had2.R")

# %%
# Run the MSE script
library(gadgetr)
updateRecruitment <- updateSpawningRec
source("flr-gadget_had2.R", echo = TRUE)
# Out:
# > Sys.setenv(R_REMOTES_NO_ERRORS_FROM_WARNINGS = "TRUE")
#
# > library(mse)
# Loading required package: FLCore
#
# Loading required package: lattice
#
# Loading required package: iterators
#
# FLCore (Version 2.6.15, packaged: 2020-05-27 21:04:10 UTC)
#
# Loading required package: ggplotFL
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘ggplot2’
#
#
# The following object is masked from ‘package:FLCore’:
#
#     %+%
#
#
# Loading required package: data.table
#
# Loading required package: FLash
#
# Loading required package: FLBRP
# > library(dplyr)
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:FLCore’:
#
#     combine, desc, intersect, n
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# > library(FLa4a)
# ...
